# %% [markdown]
# TOPIC:
#
# Currency Exchange rate forecasting(USD -> INR)
#
# Forecast the USD/INR exchange rate using historical data with a classical time series modeling pipeline and deploy the trained model using FastAPI or Streamlit

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# %%
pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting yfinance
#   Downloading yfinance-0.2.66-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from yfinance) (2.2.4)
# Requirement already satisfied: requests>=2.31 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-py313-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.2.tar.gz (949 kB)
#      ---------------------------------------- 0.0/949.2 kB ? eta -:--:--
#      ---------------------------------------- 949.2/949.2 kB 6.8 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from yfinance) (4.13.3)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from yfinance) (6.32.0)
# Requirement already satisfied: websockets>=13.0 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.13.1)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from curl_cffi>=0.7->yfinance) (2025.1.31)
# Requirement already satisfied: pycparser in c:\users\yashv\appdata\roaming\python\python313\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yashv\appdata\roaming\python\python313\site-packages (from requests>=2.31->yfinance) (2.3.0)
# Downloading yfinance-0.2.66-py2.py3-none-any.whl (123 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 10.0 MB/s  0:00:00
# Downloading frozendict-2.4.6-py313-none-any.whl (16 kB)
# Building wheels for collected packages: multitasking, peewee
#   Building wheel for multitasking (setup.py): started
#   Building wheel for multitasking (setup.py): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15702 sha256=761a0140280bc74dd0b51a088d90902ed09d9f62306f5cad1915beb74b86352d
#   Stored in directory: c:\users\yashv\appdata\local\pip\cache\wheels\1e\df\0f\e2bbb22d689b30c681feb5410ab64a2523437b34c8ecfc6476
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.2-py3-none-any.whl size=139153 sha256=95a34eb562d03821782a5a05a7db651bb84d0f3f762fcef8dbd4011aeae93e42
#   Stored in directory: c:\users\yashv\appdata\local\pip\cache\wheels\1c\48\cc\00b7d0e7defa21a58915654917c89eaedd32a6e614d8e4ad92
# Successfully built multitasking peewee
# Installing collected packages: peewee, multitasking, frozendict, curl_cffi, yfinance
#
#    ---------------------------------------- 0/5 [peewee]
#    ---------------------------------------- 0/5 [peewee]
#    ---------------------------------------- 0/5 [peewee]
#    ---------------------------------------- 0/5 [peewee]
#    ---------------------------------------- 0/5 [peewee]
#    ---------------------------------------- 0/5 [peewee]
#    ---------------------------------------- 0/5 [peewee]
#    -------- ------------------------------- 1/5 [multitasking]
#    ---------------- ----------------------- 2/5 [frozendict]
#    ------------------------ --------------- 3/5 [curl_cffi]
#    ------------------------ --------------- 3/5 [curl_cffi]
#    ------------------------ --------------- 3/5 [curl_cffi]
#    ------------------------ --------------- 3/5 [curl_cffi]
#    ------------------------ --------------- 3/5 [curl_cffi]
#    ------------------------ --------------- 3/5 [curl_cffi]
#    ------------------------ --------------- 3/5 [curl_cffi]
#    ------------------------ --------------- 3/5 [curl_cffi]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    -------------------------------- ------- 4/5 [yfinance]
#    ---------------------------------------- 5/5 [yfinance]
#
# Successfully installed curl_cffi-0.13.0 frozendict-2.4.6 multitasking-0.0.12 peewee-3.18.2 yfinance-0.2.66
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'multitasking' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'multitasking'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# 1. Data Collection
# - using yahoo finance api
# - last 10 years of data

# %%
end_date = (datetime.now()-timedelta(days=2))

start_date = end_date - timedelta(days=365*10)

print(f"\nData Range: {start_date.date()} to {end_date.date()}")
# Out:
# Data Range: 2015-10-27 to 2025-10-24

# %%
usd_inr = yf.download('INR=X', start=start_date, end=end_date, progress=False)

# %%
usd_inr
# Out:
# Price           Close       High        Low       Open Volume
# Ticker          INR=X      INR=X      INR=X      INR=X  INR=X
# Date
# 2015-10-27  64.901001  65.060997  64.879997  64.899002      0
# 2015-10-28  65.067001  65.110001  64.820000  65.072998      0
# 2015-10-29  64.945999  65.410004  64.945999  64.945999      0
# 2015-10-30  65.444000  65.445000  65.108002  65.445000      0
# 2015-11-02  65.415001  65.642998  65.260002  65.415001      0
# ...               ...        ...        ...        ...    ...
# 2025-10-20  88.002296  88.011299  87.499603  88.002296      0
# 2025-10-21  87.879997  88.083603  87.841904  87.879997      0
# 2025-10-22  88.001602  87.998100  87.610397  88.001602      0
# 2025-10-23  87.740303  88.031097  87.716103  87.740303      0
# 2025-10-24  87.778999  87.858299  87.636002  87.778999      0
#
# [2603 rows x 5 columns]

# %%
usd_inr.columns
# Out:
# MultiIndex([( 'Close', 'INR=X'),
#             (  'High', 'INR=X'),
#             (   'Low', 'INR=X'),
#             (  'Open', 'INR=X'),
#             ('Volume', 'INR=X')],
#            names=['Price', 'Ticker'])

# %% [markdown]
# now will select only the “Close” price column from  multi-indexed Yahoo Finance data and rename it to 'USD_INR'.
#
# This creates a clean, single-index DataFrame that’s easier to use in time series analysis.

# %%
df = pd.DataFrame({
    'USD_INR': usd_inr[('Close', 'INR=X')]
})

# %%
df
# Out:
#               USD_INR
# Date
# 2015-10-27  64.901001
# 2015-10-28  65.067001
# 2015-10-29  64.945999
# 2015-10-30  65.444000
# 2015-11-02  65.415001
# ...               ...
# 2025-10-20  88.002296
# 2025-10-21  87.879997
# 2025-10-22  88.001602
# 2025-10-23  87.740303
# 2025-10-24  87.778999
#
# [2603 rows x 1 columns]

# %%
print(f"Collected {len(df)} days of USD/INR data")
print(f"Range: {df['USD_INR'].min():.4f} to {df['USD_INR'].max():.4f}")
# Out:
# Collected 2603 days of USD/INR data
# Range: 63.2650 to 88.8654

# %% [markdown]
# the above specifies that data was collected for 2603 market days and not calender days, with minimum value being 64.265 and max being 88.86

# %%
#daily data
# Save daily data
df.to_csv('usd_inr_daily_raw.csv')
print(f" Daily data saved: usd_inr_daily_raw.csv ({len(df)} rows)")
# Out:
#  Daily data saved: usd_inr_daily_raw.csv (2603 rows)

# %%
print("\nDAILY DATA:")
print(f"  Date Range: {df.index[0].date()} to {df.index[-1].date()}")
print(f"  Total Days: {len(df)}")
print(f"  Trading Days: {df['USD_INR'].notna().sum()}")
# Out:
# DAILY DATA:
#   Date Range: 2015-10-27 to 2025-10-24
#   Total Days: 2603
#   Trading Days: 2603

# %%
print("\n Daily Statss:")
print(df['USD_INR'].describe())
# Out:
#  Daily Statss:
# count    2603.000000
# mean       74.709749
# std         7.201498
# min        63.264999
# 25%        68.129749
# 50%        73.824097
# 75%        82.418648
# max        88.865402
# Name: USD_INR, dtype: float64
